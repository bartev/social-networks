# %%
import networkx as nx
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from social_networks.describe import describe_graph
import social_networks.visualize as viz

# %matplotlib widget

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1

# %% [markdown]
# Clustering coeff
#
# 5 neighbors
# 5 * 4 / 2 = 10 possible pairs
# 7 pairs of friends are friends
#
# LCC of F = 7/10

# %% [markdown]
# # 2

# %% [markdown]
# $$\text{transitivity} = \frac{3 \times \text{num closed triads}}{\text{num open triads}}$$

# %% [markdown]
# 14 open
# 3 closed

# %%
3 * 3/ 20
# Out:
# 0.45

# %% [markdown]
# 16 open triads
# 4 closed triads
# 3 * 4 / 16 = 0.75 = transitivity

# %% [markdown]
# # 3

# %% [markdown]
# radius = 2 (D)
# Diameter = 4 (A-F)
#
# G disconnects
#
# BFS from A has depth 4
#
# F is in periphery, but so is
#
# B & C have eccentricity = 3

# %% [markdown]
# # 4

# %% [markdown]
# Disconnected & 2 connected components
#
# LCC for I
# I: 2 friends
# J: 1 friend
# LCC of node degree < 2 == 0

# %% [markdown]
# # 5

# %% [markdown]
# Only B is strongly connected
# Only need to add 1 directed component to make C strongly connected

# %% [markdown]
# # 6 - wrong

# %% [markdown]
# Closure of airport or cancellation of route are 2 kinds of network attacks
# Adding more edges always makes network more robust
# Network robustness measures ability to maintain connectivity
# Adding edges cannot make network less robust

# %% [markdown]
# # 7

# %% [markdown]
# Node connectivity = 1

# %% [markdown]
# # 8

# %% [markdown]
# Edge connectivity = 2

# %% [markdown]
# # 9

# %% [markdown]
# 8 simple paths from D to K

# %% [markdown]
# # 10

# %% [markdown]
# Remove nodes F & H
# Remove edges (H,K) & (E,F)
